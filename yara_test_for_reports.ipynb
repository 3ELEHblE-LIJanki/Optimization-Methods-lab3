# %%
import time
import numpy as np
import sys
from ucimlrepo import fetch_ucirepo

sys.path.insert(0, "./Optimization-lib")
from gradient_descent import GradientDecent
from stochastic_gradient_descent import StochGradientDecent
from function_wrapper import FunctionWrapper
from lrs import exponential_decay, gradient
from output import pretty_dataset_print
from all_stats import measure_resources

wine_quality = fetch_ucirepo(id=186)
X = wine_quality.data.features.values
y = wine_quality.data.targets.values.ravel()

def normalize(X_train):
    mean = X_train.mean(axis=0)
    std = X_train.std(axis=0)
    std[std == 0] = 1
    return (X_train - mean) / std

X = normalize(X)

def generate_weight_bounds(X, abs_bound):
    return [[-abs_bound, abs_bound] for _ in range(X.shape[1] + 1)]

def generate_start(X):
    return [1 for _ in range(X.shape[1] + 1)]

bounds = generate_weight_bounds(X, 1000)
start = generate_start(X)


sgd = StochGradientDecent(
    exponential_decay(0.01, 0.0001),
    bounds,
    X, y,
    batch_size=5
)
error_min_sgd = sgd.find_min(start, 1000000)
time_sgd, mem_sgd, cpu_sgd = measure_resources(sgd.find_min, start, 1000000)
print(f"SGD результаты:")
print(f"Время: {time_sgd:.2f} сек")
print(f"Пиковое использование памяти: {mem_sgd:.2f} MiB")
print(f"Использование CPU: {cpu_sgd:.2f}%\n")


def create_mse_function(X, y):
    def mse(weights):
        predictions = weights[0] + X.dot(weights[1:])
        return np.mean((y - predictions) ** 2)
    return FunctionWrapper(mse)
mse_func = create_mse_function(X, y)
gd = GradientDecent(
    exponential_decay(0.01, 0.0001),
    mse_func,
    bounds,
    0.0001
)
error_min_gd = gd.find_min(start, 1000)
time_gd, mem_gd, cpu_gd = measure_resources(gd.find_min, start, 1000)
print(f"GD результаты:")
print(f"Время: {time_gd:.2f} сек")
print(f"Пиковое использование памяти: {mem_gd:.2f} MiB")
print(f"Использование CPU: {cpu_gd:.2f}%\n")
# Out:
# SGD результаты:
# Время: 364.07 сек
# Пиковое использование памяти: 45.92 MiB
# Использование CPU: 97.10%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 62
#      55 mse_func = create_mse_function(X, y)
#      56 gd = GradientDecent(
#      57     exponential_decay(0.01, 0.0001),
#      58     mse_func,
#      59     bounds,
#      60     0.0001
#      61 )
# ---> 62 error_min_gd = gd.find_min(start, 1000)
#      63 time_gd, mem_gd, cpu_gd = measure_resources(gd.find_min, start, 1000)
#      64 print(f"GD результаты:")
#
# File c:\Users\yaros\OneDrive\Desktop\ITMO\Optimization-Methods\Optimization-Methods-lab3\Optimization-lib\gradient_descent.py:59, in GradientDecent.find_min(self, start, max_iterations)
#      52 def find_min(self, start: List[float], max_iterations: int) -> float:
#      53     """
#      54         :param  start: List[float] - стартовая точка, в которой начнём поиск
#      55         :param  max_iterations: int - максимальное количество итераций спуска
#      56         :return: - минимум полученный в ходе спуска
#      57     """
# ---> 59     return self.__find(start, max_iterations, lambda x, y: x - y)
#
# File c:\Users\yaros\OneDrive\Desktop\ITMO\Optimization-Methods\Optimization-Methods-lab3\Optimization-lib\gradient_descent.py:40, in GradientDecent.__find(self, start, max_iterations, op)
#      38 h = self.learning_rate_scheduling(self.x, i, self.f, self.bounds)
#      39 self.path.append(self.x)
# ---> 40 grad = self.gradient(self.f, self.x, self.eps)
#      41 xx = []
#      42 for j in range(len(self.x)):
#
# File c:\Users\yaros\OneDrive\Desktop\ITMO\Optimization-Methods\Optimization-Methods-lab3\Optimization-lib\function_wrapper.py:30, in FunctionWrapper.__call__(self, *args)
#      29 def __call__(self, *args) -> float:
# ---> 30     key = self._make_cache_key(args)
#      31     if key in self._cache:
#      32         return self._cache[key]
#
# File c:\Users\yaros\OneDrive\Desktop\ITMO\Optimization-Methods\Optimization-Methods-lab3\Optimization-lib\function_wrapper.py:24, in FunctionWrapper._make_cache_key(self, args)
#      20 """
#      21 Создаёт хеш-ключ для кэша на основе аргументов.
#      22 """
#      23 try:
# ---> 24     raw = dill.dumps(args)
#      25 except Exception:
#      26     raw = repr(args).encode('utf-8')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:288, in dumps(obj, protocol, byref, fmode, recurse, **kwds)
#     264 """
#     265 Pickle an object to a string.
#     266
#    (...)    285 Default values for keyword arguments can be set in :mod:`dill.settings`.
#     286 """
#     287 file = StringIO()
# --> 288 dump(obj, file, protocol, byref, fmode, recurse, **kwds)#, strictio)
#     289 return file.getvalue()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:260, in dump(obj, file, protocol, byref, fmode, recurse, **kwds)
#     258 _kwds = kwds.copy()
#     259 _kwds.update(dict(byref=byref, fmode=fmode, recurse=recurse))
# --> 260 Pickler(file, protocol, **_kwds).dump(obj)
#     261 return
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:428, in Pickler.dump(self, obj)
#     426 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     427     logger.trace_setup(self)
# --> 428     StockPickler.dump(self, obj)
#
# File c:\Program Files\Python313\Lib\pickle.py:484, in _Pickler.dump(self, obj)
#     482 if self.proto >= 4:
#     483     self.framer.start_framing()
# --> 484 self.save(obj)
#     485 self.write(STOP)
#     486 self.framer.end_framing()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File c:\Program Files\Python313\Lib\pickle.py:904, in _Pickler.save_tuple(self, obj)
#     902 if n <= 3 and self.proto >= 2:
#     903     for element in obj:
# --> 904         save(element)
#     905     # Subtle.  Same as in the big comment below.
#     906     if id(obj) in memo:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:600, in _Pickler.save(self, obj, save_persistent_id)
#     596     raise PicklingError("Tuple returned by %s must have "
#     597                         "two to six elements" % reduce)
#     599 # Save the reduce() output and finally memoize the object
# --> 600 self.save_reduce(obj=obj, *rv)
#
# File c:\Program Files\Python313\Lib\pickle.py:714, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     712 if state is not None:
#     713     if state_setter is None:
# --> 714         save(state)
#     715         write(BUILD)
#     716     else:
#     717         # If a state_setter is specified, call it instead of load_build
#     718         # to update obj's with its previous state.
#     719         # First, push state_setter and its tuple of expected arguments
#     720         # (obj, state) onto the stack.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:1262, in save_module_dict(pickler, obj)
#    1259     if is_dill(pickler, child=False) and pickler._session:
#    1260         # we only care about session the first pass thru
#    1261         pickler._first_pass = False
# -> 1262     StockPickler.save_dict(pickler, obj)
#    1263     logger.trace(pickler, "# D2")
#    1264 return
#
# File c:\Program Files\Python313\Lib\pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File c:\Program Files\Python313\Lib\pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:1262, in save_module_dict(pickler, obj)
#    1259     if is_dill(pickler, child=False) and pickler._session:
#    1260         # we only care about session the first pass thru
#    1261         pickler._first_pass = False
# -> 1262     StockPickler.save_dict(pickler, obj)
#    1263     logger.trace(pickler, "# D2")
#    1264 return
#
# File c:\Program Files\Python313\Lib\pickle.py:989, in _Pickler.save_dict(self, obj)
#     986     self.write(MARK + DICT)
#     988 self.memoize(obj)
# --> 989 self._batch_setitems(obj.items())
#
# File c:\Program Files\Python313\Lib\pickle.py:1013, in _Pickler._batch_setitems(self, items)
#    1011     for k, v in tmp:
#    1012         save(k)
# -> 1013         save(v)
#    1014     write(SETITEMS)
#    1015 elif n:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:600, in _Pickler.save(self, obj, save_persistent_id)
#     596     raise PicklingError("Tuple returned by %s must have "
#     597                         "two to six elements" % reduce)
#     599 # Save the reduce() output and finally memoize the object
# --> 600 self.save_reduce(obj=obj, *rv)
#
# File c:\Program Files\Python313\Lib\pickle.py:689, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     687 else:
#     688     save(func)
# --> 689     save(args)
#     690     write(REDUCE)
#     692 if obj is not None:
#     693     # If the object is already in the memo, this means it is
#     694     # recursive. In this case, throw away everything we put on the
#     695     # stack, and fetch the object back from the memo.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:422, in Pickler.save(self, obj, save_persistent_id)
#     420     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     421     raise PicklingError(msg)
# --> 422 StockPickler.save(self, obj, save_persistent_id)
#
# File c:\Program Files\Python313\Lib\pickle.py:557, in _Pickler.save(self, obj, save_persistent_id)
#     555 f = self.dispatch.get(t)
#     556 if f is not None:
# --> 557     f(self, obj)  # Call unbound method with explicit self
#     558     return
#     560 # Check private dispatch table if any, or else
#     561 # copyreg.dispatch_table
#
# File c:\Program Files\Python313\Lib\pickle.py:904, in _Pickler.save_tuple(self, obj)
#     902 if n <= 3 and self.proto >= 2:
#     903     for element in obj:
# --> 904         save(element)
#     905     # Subtle.  Same as in the big comment below.
#     906     if id(obj) in memo:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:408, in Pickler.save(self, obj, save_persistent_id)
#     401         return
#     402     # NOTE: the above 'save' performs like:
#     403     #   import copy_reg
#     404     #   def uload(name): return type(NumpyDType(name))
#     405     #   def udump(f): return uload, (f.type,)
#     406     #   copy_reg.pickle(NumpyDTypeType, udump, uload)
#     407 # register if the object is a subclassed numpy array instance
# --> 408 if ndarraysubclassinstance(obj_type):
#     409     @register(obj_type)
#     410     def save_numpy_array(pickler, obj):
#     411         logger.trace(pickler, "Nu: (%s, %s)", obj.shape, obj.dtype)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:121, in ndarraysubclassinstance(obj_type)
#     120 def ndarraysubclassinstance(obj_type):
# --> 121     if all((c.__module__, c.__name__) != ('numpy', 'ndarray') for c in obj_type.__mro__):
#     122         return False
#     123     # anything below here is a numpy array (or subclass) instance
#
# File ~\AppData\Roaming\Python\Python313\site-packages\dill\_dill.py:121, in <genexpr>(.0)
#     120 def ndarraysubclassinstance(obj_type):
# --> 121     if all((c.__module__, c.__name__) != ('numpy', 'ndarray') for c in obj_type.__mro__):
#     122         return False
#     123     # anything below here is a numpy array (or subclass) instance
#
# KeyboardInterrupt:
